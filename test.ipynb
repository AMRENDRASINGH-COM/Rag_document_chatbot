# %%
from app.ingest import load_txt, load_pdf
from app.retriever import embed_texts
from app.rag_graph import rag
docs_txt = load_txt("data/input.txt")
docs_pdf = load_pdf("data/doc.pdf")
DOCUMENTS = docs_txt + docs_pdf
DOC_EMBEDDINGS = embed_texts(DOCUMENTS)

# %%
question = "What is google adk?"
answer, contexts, confidence = rag(question, DOCUMENTS, DOC_EMBEDDINGS, k=2)

print(f"Q: {question}")
print(f"A: {answer}")
print(f"Confidence: {confidence}")
# Out:
# Q: What is google adk?
# A: Google Agent Development Kit (ADK) is a flexible, modular framework designed for developing, deploying, and orchestrating AI agents. It is optimized for Gemini and the Google ecosystem but is also deployment-agnostic, offering compatibility with other frameworks. ADK aims to make agent development similar to software development, enabling the creation and management of agentic architectures ranging from simple tasks to complex workflows.
# Confidence: 0.59

# %%
question = "Who invented AI?"
answer, contexts, confidence = rag(question, DOCUMENTS, DOC_EMBEDDINGS, k=2)

print(f"Q: {question}")
print(f"A: {answer}")
print(f"Confidence: {confidence}")
# Out:
# Q: Who invented AI?
# A: The context provided does not specify a single inventor of AI. Marvin Minsky is mentioned as a cofounder of the MIT AI Lab and as someone who advanced early robotics and cognitive models, but the context does not credit him or any individual as the sole inventor of AI. AI development is the result of contributions from many researchers and scientists over time.
# Confidence: 0.62

# %%
question = "what is challange to intigrate langgraph with google adk?"
answer, contexts, confidence = rag(question, DOCUMENTS, DOC_EMBEDDINGS, k=2)

print(f"Q: {question}")
print(f"A: {answer}")
print(f"Confidence: {confidence}")
# Out:
# Q: what is challange to intigrate langgraph with google adk?
# A: The challenge with integrating LangGraph with Google ADK is that the Google ADK agent serves as the main orchestrator, while the LangGraph agent is integrated into ADK as a tool.
# Confidence: 0.49

# %%
question = "Who Is Narendra Modi?"
answer, contexts, confidence = rag(question, DOCUMENTS, DOC_EMBEDDINGS, k=2)

print(f"Q: {question}")
print(f"A: {answer}")
print(f"Confidence: {confidence}")
# Out:
# Q: Who Is Narendra Modi?
# A: The context provided does not include any information about Narendra Modi.
# Confidence: 0.15
